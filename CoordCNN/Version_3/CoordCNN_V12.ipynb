# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.lib.stride_tricks import sliding_window_view
from sklearn.preprocessing import MinMaxScaler

def scaled_trainer(arr, lb, lf, choice):
    sc = MinMaxScaler(feature_range=(-1,1))
    tx = np.array([])
    ty = np.array([])
    t = np.array([])
    tx_new = np.array([])

    for i in arr:
        data = pd.read_csv(i).filter([choice]).values
        data = sc.fit_transform(data)
        t = np.append(t, sliding_window_view(data, window_shape = (lb+lf,1)))

    t = t.reshape(int(t.shape[0]/(lb+lf)), lb+lf)
    for j in t:
        tx = np.append(tx, j[:lb])
        ty = np.append(ty, j[lb:])
    tx = tx.reshape((int(tx.shape[0]/lb), lb))
    ty = sc.inverse_transform(ty.reshape((-1,1)))    
    #tx_new = tx_new.reshape((int(tx_new.shape[0]/(lb-1)), (lb-1)))
    ty = ty.reshape((int(ty.shape[0]/lf), lf))

    return tx, ty

lb=200
lf=20
companies = ["reliance industries.csv", "reliance power.csv", "tata steel.csv",
             "asian paints new.csv", "tata coffee.csv", "edelweiss.csv", 
             "tata chemicals.csv", "tech mahindra.csv", "infosys.csv", "tata motors.csv"]

# %%
for com in companies:
    trade_x, _ = scaled_trainer([com], lb, lf, "No. of Trades")
    shl_x, _ = scaled_trainer([com], lb, lf, "Spread High-Low")
    wap_x, wap_y = scaled_trainer([com], lb, lf, "WAP")
    # open_x, _ = scaled_trainer([com], lb, lf, "Open Price")
    # sco_x, _ = scaled_trainer([com], lb, lf, "Spread Close-Open")
    day_x, _ = scaled_trainer([com], lb, lf, "Date_val")
    
    wap_img = np.array([])
    shl_img = np.array([])
    trade_img = np.array([])
    # sco_img = np.array([])
    # open_img = np.array([])
    day_img = np.array([])
    for i in range(len(wap_x)):
        eps = 0.1
        d1 = np.abs(np.subtract.outer(wap_x[i],wap_x[i]))
        R1 = np.exp(-d1**2/eps)
        wap_img = np.append(wap_img, [R1])
        d2 = np.abs(np.subtract.outer(shl_x[i],shl_x[i]))
        R2 = np.exp(-d2**2/eps)
        shl_img = np.append(shl_img, [R2])
        d3 = np.abs(np.subtract.outer(trade_x[i],trade_x[i]))
        R3 = np.exp(-d3**2/eps)
        trade_img = np.append(trade_img, [R3]) 
        # d4 = np.abs(np.subtract.outer(sco_x[i],sco_x[i]))
        # R4 = np.exp(-d3**2/eps)
        # sco_img = np.append(sco_img, [R4]) 
        # d5 = np.abs(np.subtract.outer(open_x[i],open_x[i]))
        # R5 = np.exp(-d3**2/eps)
        # open_img = np.append(open_img, [R5]) 
        d6 = np.abs(np.subtract.outer(day_x[i],day_x[i]))
        R6 = np.exp(-d6**2/eps)
        day_img = np.append(day_img, [R6])
        
    wap_img = wap_img.reshape((int(wap_img.shape[0]/(lb*lb)), lb, lb, 1))
    shl_img = shl_img.reshape((int(shl_img.shape[0]/(lb*lb)), lb, lb, 1))
    trade_img = trade_img.reshape((int(trade_img.shape[0]/(lb*lb)), lb, lb, 1))
    # sco_img = sco_img.reshape((int(sco_img.shape[0]/(lb*lb)), lb, lb, 1))
    # open_img = open_img.reshape((int(open_img.shape[0]/(lb*lb)), lb, lb, 1))
    day_img = day_img.reshape((int(day_img.shape[0]/(lb*lb)), lb, lb, 1))

    x = np.arange(1,lf+1)
    slopes = np.array([])
    direction = np.array([])
    for i in wap_y:
        m, _ = np.polyfit(x, i, 1)
        a, b, _ = np.polyfit(x, i, 2)
        slopes = np.append(slopes, np.array([m, a]))
        #direction = np.append(direction, np.array([a,b,_]))

    slopes = slopes.reshape((int(slopes.shape[0]/2), 2))
    #direction = direction.reshape((int(direction.shape[0]/3), 3))
    model_out = np.array([])
    for i in slopes:
        if i[0]<0:
            i[0] = 0
        else:
            i[0] = 1
        if i[1]<0:
            i[1] = 0
        else:
            i[1] = 1
  
        #     if i[1]<0:
        #         model_out = np.append(model_out, 0)
        #     else:
        #         model_out = np.append(model_out, 1)
        # else:
        #     if i[1]<0:
        #         model_out = np.append(model_out, 2)
        #     else:
        #         model_out = np.append(model_out, 3)
    
    bins = np.arange(0, 3)
    hist, _ = np.histogram(slopes[:, 0], bins=2)
    plt.bar(bins[:-1], hist, align='center')
    plt.xticks(bins[:-1])
    plt.show()
    bins = np.arange(0, 3)
    hist, _ = np.histogram(slopes[:, 1], bins=2)
    plt.bar(bins[:-1], hist, align='center')
    plt.xticks(bins[:-1])
    plt.show()

    model_in = wap_img
    # model_in = np.append(model_in, open_img, axis=3)
    model_in = np.append(model_in, shl_img, axis=3)
    # model_in = np.append(model_in, sco_img, axis=3)
    model_in = np.append(model_in, trade_img, axis=3)
    model_in = np.append(model_in, day_img, axis=3)

    np.save(f"input {com[:-4]}", model_in)
    np.save(f"output {com[:-4]}", slopes)
    print(f"Saved data on {com[:-4]}: Input/Output", model_in.shape, slopes.shape)
# Out:
# Saved data on reliance industries: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on reliance power: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on tata steel: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on asian paints new: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on tata coffee: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on edelweiss: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on tata chemicals: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on tech mahindra: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on infosys: Input/Output (1267, 200, 200, 4) (1267, 2)
# Saved data on tata motors: Input/Output (1267, 200, 200, 4) (1267, 2)

# %%
from tensorflow.python.layers import base
import tensorflow as tf
from tensorflow import keras
from keras import layers

class AddCoords(base.Layer):
    """Add coords to a tensor"""
    def __init__(self, x_dim=lb, y_dim=lb, with_r=False):
        super(AddCoords, self).__init__()
        self.x_dim = x_dim
        self.y_dim = y_dim
        self.with_r = with_r
    def call(self, input_tensor):
        """
        input_tensor: (batch, x_dim, y_dim, c)
        """
        batch_size_tensor = tf.shape(input_tensor)[0]
        xx_ones = tf.ones([batch_size_tensor, self.x_dim], dtype=tf.int32)
        xx_ones = tf.expand_dims(xx_ones, -1)
        xx_range = tf.tile(tf.expand_dims(tf.range(self.y_dim), 0), [batch_size_tensor, 1])
        xx_range = tf.expand_dims(xx_range, 1)
        xx_channel = tf.matmul(xx_ones, xx_range)
        xx_channel = tf.expand_dims(xx_channel, -1)
        yy_ones = tf.ones([batch_size_tensor, self.y_dim], dtype=tf.int32)
        yy_ones = tf.expand_dims(yy_ones, 1)
        yy_range = tf.tile(tf.expand_dims(tf.range(self.x_dim), 0), [batch_size_tensor, 1])
        yy_range = tf.expand_dims(yy_range, -1)
        yy_channel = tf.matmul(yy_range, yy_ones)
        yy_channel = tf.expand_dims(yy_channel, -1)
        xx_channel = tf.cast(xx_channel, 'float32') / (self.x_dim - 1)
        yy_channel = tf.cast(yy_channel, 'float32') / (self.y_dim - 1)
        xx_channel = xx_channel*2 - 1
        yy_channel = yy_channel*2 - 1
        ret = tf.concat([input_tensor, xx_channel, yy_channel], axis=-1)
        if self.with_r:
            rr = tf.sqrt( tf.square(xx_channel) + tf.square(yy_channel))
            ret = tf.concat([ret, rr], axis=-1)
        return ret

class CoordConv(base.Layer):
    """CoordConv layer as in the paper."""
    def __init__(self, x_dim, y_dim, with_r, *args, **kwargs):
        super(CoordConv, self).__init__()
        self.addcoords = AddCoords(x_dim=x_dim,
        y_dim=y_dim,
        with_r=with_r)
        self.conv = layers.Conv2D(*args, **kwargs)
    def call(self, input_tensor):
        ret = self.addcoords(input_tensor)
        ret = self.conv(ret)
        return ret

# %%
def inception_module(inputs, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool):
    # 1x1 conv layer
    conv_1x1 = tf.keras.layers.Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(inputs)

    # 3x3 conv layer
    conv_3x3_reduce = tf.keras.layers.Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(inputs)
    conv_3x3 = tf.keras.layers.Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3_reduce)

    # 5x5 conv layer
    conv_5x5_reduce = tf.keras.layers.Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(inputs)
    conv_5x5 = tf.keras.layers.Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5_reduce)

    # Max pooling layer
    max_pool = tf.keras.layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(inputs)
    max_pool_conv = tf.keras.layers.Conv2D(filters_pool, (1, 1), padding='same', activation='relu')(max_pool)

    # Concatenate the outputs of all conv layers
    outputs = tf.keras.layers.Concatenate(axis=-1)([conv_1x1, conv_3x3, conv_5x5, max_pool_conv])

    return outputs

# %%
addcoords = AddCoords()
input1 = keras.Input(shape=(lb,lb,1), name="wap")
# input2 = keras.Input(shape=(lb,lb,1), name="open")
input3 = keras.Input(shape=(lb,lb,1), name="shl")
# input4 = keras.Input(shape=(lb,lb,1), name="sco")
input5 = keras.Input(shape=(lb,lb,1), name="trades")
input6 = keras.Input(shape=(lb,lb,1), name="date_val")
inputs = layers.Concatenate(axis=-1)([input1, input3, input5, input6])
inputs = addcoords(inputs)
x = layers.Conv2D(64, 5, padding='same', activation='relu')(inputs)
x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.Dropout(0.2)(x)
x = inception_module(x, 128, 112, 64, 64, 32, 32)
x = inception_module(x, 256, 200, 128, 128, 112, 112)
x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.Dropout(0.2)(x)
x = inception_module(x, 192, 96, 208, 16, 48, 64)
x = inception_module(x, 160, 112, 224, 24, 64, 64)
x = inception_module(x, 128, 128, 256, 24, 64, 64)
x = layers.Dropout(0.2)(x)
x = inception_module(x, 256, 160, 320, 32, 128, 128)
x = inception_module(x, 384, 192, 384, 48, 128, 128)
x = inception_module(x, 384, 192, 384, 64, 256, 256)
x = layers.GlobalMaxPool2D()(x)
x = layers.Dropout(0.2)(x)
output2 = layers.Dense(2, activation='softmax', name='out2')(x)
seer = keras.Model([input1, input3, input5, input6], output2, name='seer')
seer.summary()
# Out:
# Model: "seer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  wap (InputLayer)               [(None, 200, 200, 1  0           []
#                                 )]
#
#  shl (InputLayer)               [(None, 200, 200, 1  0           []
#                                 )]
#
#  trades (InputLayer)            [(None, 200, 200, 1  0           []
#                                 )]
#
#  date_val (InputLayer)          [(None, 200, 200, 1  0           []
#                                 )]
#
#  concatenate_9 (Concatenate)    (None, 200, 200, 4)  0           ['wap[0][0]',
#                                                                   'shl[0][0]',
#                                                                   'trades[0][0]',
#                                                                   'date_val[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (4,)                0           ['concatenate_9[0][0]']
#  da)
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.ones_2 (TFOpLambda)         (None, 200)          0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.tile_2 (TFOpLambda)         (None, 200)          0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.tile_3 (TFOpLambda)         (None, 200)          0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.ones_3 (TFOpLambda)         (None, 200)          0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.expand_dims_6 (TFOpLambda)  (None, 200, 1)       0           ['tf.ones_2[0][0]']
#
#  tf.expand_dims_7 (TFOpLambda)  (None, 1, 200)       0           ['tf.tile_2[0][0]']
#
#  tf.expand_dims_10 (TFOpLambda)  (None, 200, 1)      0           ['tf.tile_3[0][0]']
#
#  tf.expand_dims_9 (TFOpLambda)  (None, 1, 200)       0           ['tf.ones_3[0][0]']
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 200, 200)    0           ['tf.expand_dims_6[0][0]',
#  )                                                                'tf.expand_dims_7[0][0]']
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 200, 200)    0           ['tf.expand_dims_10[0][0]',
#  )                                                                'tf.expand_dims_9[0][0]']
#
#  tf.expand_dims_8 (TFOpLambda)  (None, 200, 200, 1)  0           ['tf.linalg.matmul_2[0][0]']
#
#  tf.expand_dims_11 (TFOpLambda)  (None, 200, 200, 1)  0          ['tf.linalg.matmul_3[0][0]']
#
#  tf.cast_2 (TFOpLambda)         (None, 200, 200, 1)  0           ['tf.expand_dims_8[0][0]']
#
#  tf.cast_3 (TFOpLambda)         (None, 200, 200, 1)  0           ['tf.expand_dims_11[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 200, 200, 1)  0          ['tf.cast_2[0][0]']
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 200, 200, 1)  0          ['tf.cast_3[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 200, 200, 1)  0          ['tf.math.truediv_2[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 200, 200, 1)  0          ['tf.math.truediv_3[0][0]']
#  )
#
#  tf.math.subtract_2 (TFOpLambda  (None, 200, 200, 1)  0          ['tf.math.multiply_2[0][0]']
#  )
#
#  tf.math.subtract_3 (TFOpLambda  (None, 200, 200, 1)  0          ['tf.math.multiply_3[0][0]']
#  )
#
#  tf.concat_1 (TFOpLambda)       (None, 200, 200, 6)  0           ['concatenate_9[0][0]',
#                                                                   'tf.math.subtract_2[0][0]',
#                                                                   'tf.math.subtract_3[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 200, 200, 64  9664        ['tf.concat_1[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 100, 100, 64  0          ['conv2d_49[0][0]']
#  )                              )
#
#  dropout_4 (Dropout)            (None, 100, 100, 64  0           ['max_pooling2d_10[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 100, 100, 11  7280        ['dropout_4[0][0]']
#                                 2)
#
#  conv2d_53 (Conv2D)             (None, 100, 100, 64  4160        ['dropout_4[0][0]']
#                                 )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 100, 100, 64  0          ['dropout_4[0][0]']
#  )                              )
#
#  conv2d_50 (Conv2D)             (None, 100, 100, 12  8320        ['dropout_4[0][0]']
#                                 8)
#
#  conv2d_52 (Conv2D)             (None, 100, 100, 64  64576       ['conv2d_51[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 100, 100, 32  51232       ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 100, 100, 32  2080        ['max_pooling2d_11[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 100, 100, 25  0           ['conv2d_50[0][0]',
#                                 6)                                'conv2d_52[0][0]',
#                                                                   'conv2d_54[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 100, 100, 20  51400       ['concatenate_10[0][0]']
#                                 0)
#
#  conv2d_59 (Conv2D)             (None, 100, 100, 12  32896       ['concatenate_10[0][0]']
#                                 8)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 100, 100, 25  0          ['concatenate_10[0][0]']
#  )                              6)
#
#  conv2d_56 (Conv2D)             (None, 100, 100, 25  65792       ['concatenate_10[0][0]']
#                                 6)
#
#  conv2d_58 (Conv2D)             (None, 100, 100, 12  230528      ['conv2d_57[0][0]']
#                                 8)
#
#  conv2d_60 (Conv2D)             (None, 100, 100, 11  358512      ['conv2d_59[0][0]']
#                                 2)
#
#  conv2d_61 (Conv2D)             (None, 100, 100, 11  28784       ['max_pooling2d_12[0][0]']
#                                 2)
#
#  concatenate_11 (Concatenate)   (None, 100, 100, 60  0           ['conv2d_56[0][0]',
#                                 8)                                'conv2d_58[0][0]',
#                                                                   'conv2d_60[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 50, 50, 608)  0          ['concatenate_11[0][0]']
#  )
#
#  dropout_5 (Dropout)            (None, 50, 50, 608)  0           ['max_pooling2d_13[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 50, 50, 96)   58464       ['dropout_5[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 50, 50, 16)   9744        ['dropout_5[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 50, 50, 608)  0          ['dropout_5[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 50, 50, 192)  116928      ['dropout_5[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 50, 50, 208)  179920      ['conv2d_63[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 50, 50, 48)   19248       ['conv2d_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 50, 50, 64)   38976       ['max_pooling2d_14[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 50, 50, 512)  0           ['conv2d_62[0][0]',
#                                                                   'conv2d_64[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 50, 50, 112)  57456       ['concatenate_12[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 50, 50, 24)   12312       ['concatenate_12[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 50, 50, 512)  0          ['concatenate_12[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 50, 50, 160)  82080       ['concatenate_12[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 50, 50, 224)  226016      ['conv2d_69[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 50, 50, 64)   38464       ['conv2d_71[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 50, 50, 64)   32832       ['max_pooling2d_15[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 50, 50, 512)  0           ['conv2d_68[0][0]',
#                                                                   'conv2d_70[0][0]',
#                                                                   'conv2d_72[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 50, 50, 128)  65664       ['concatenate_13[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 50, 50, 24)   12312       ['concatenate_13[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 50, 50, 512)  0          ['concatenate_13[0][0]']
#  )
#
#  conv2d_74 (Conv2D)             (None, 50, 50, 128)  65664       ['concatenate_13[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 50, 50, 256)  295168      ['conv2d_75[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 50, 50, 64)   38464       ['conv2d_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 50, 50, 64)   32832       ['max_pooling2d_16[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 50, 50, 512)  0           ['conv2d_74[0][0]',
#                                                                   'conv2d_76[0][0]',
#                                                                   'conv2d_78[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  dropout_6 (Dropout)            (None, 50, 50, 512)  0           ['concatenate_14[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 50, 50, 160)  82080       ['dropout_6[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 50, 50, 32)   16416       ['dropout_6[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 50, 50, 512)  0          ['dropout_6[0][0]']
#  )
#
#  conv2d_80 (Conv2D)             (None, 50, 50, 256)  131328      ['dropout_6[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 50, 50, 320)  461120      ['conv2d_81[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 50, 50, 128)  102528      ['conv2d_83[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 50, 50, 128)  65664       ['max_pooling2d_17[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 50, 50, 832)  0           ['conv2d_80[0][0]',
#                                                                   'conv2d_82[0][0]',
#                                                                   'conv2d_84[0][0]',
#                                                                   'conv2d_85[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 50, 50, 192)  159936      ['concatenate_15[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 50, 50, 48)   39984       ['concatenate_15[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 50, 50, 832)  0          ['concatenate_15[0][0]']
#  )
#
#  conv2d_86 (Conv2D)             (None, 50, 50, 384)  319872      ['concatenate_15[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 50, 50, 384)  663936      ['conv2d_87[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 50, 50, 128)  153728      ['conv2d_89[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 50, 50, 128)  106624      ['max_pooling2d_18[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 50, 50, 1024  0           ['conv2d_86[0][0]',
#                                 )                                 'conv2d_88[0][0]',
#                                                                   'conv2d_90[0][0]',
#                                                                   'conv2d_91[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 50, 50, 192)  196800      ['concatenate_16[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 50, 50, 64)   65600       ['concatenate_16[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 50, 50, 1024  0          ['concatenate_16[0][0]']
#  )                              )
#
#  conv2d_92 (Conv2D)             (None, 50, 50, 384)  393600      ['concatenate_16[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 50, 50, 384)  663936      ['conv2d_93[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 50, 50, 256)  409856      ['conv2d_95[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 50, 50, 256)  262400      ['max_pooling2d_19[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 50, 50, 1280  0           ['conv2d_92[0][0]',
#                                 )                                 'conv2d_94[0][0]',
#                                                                   'conv2d_96[0][0]',
#                                                                   'conv2d_97[0][0]']
#
#  global_max_pooling2d_1 (Global  (None, 1280)        0           ['concatenate_17[0][0]']
#  MaxPooling2D)
#
#  dropout_7 (Dropout)            (None, 1280)         0           ['global_max_pooling2d_1[0][0]']
#
#  out2 (Dense)                   (None, 2)            2562        ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 6,595,738
# Trainable params: 6,595,738
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import os
checkpoint_path = "train/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
base_learning_rate = 1e-4
seer.load_weights(checkpoint_path)
seer.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=keras.metrics.CategoricalAccuracy())

# %%
history = []
companies = ["infosys.csv", "tata steel.csv"]
for com in companies:
    model_in = np.load(f"input {com[:-4]}.npy")
    wap = model_in[:,:,:,0].reshape((-1, lb, lb, 1))
    shl = model_in[:,:,:,1].reshape((-1, lb, lb, 1))
    trades = model_in[:,:,:,2].reshape((-1, lb, lb, 1))
    dates = model_in[:,:,:,3].reshape((-1, lb, lb, 1))
    model_out = np.load(f"output {com[:-4]}.npy")
    out1 = model_out[:,0].reshape((-1,1))
    out2 = model_out[:,1].reshape((-1,1))    

    print(f"Training on {com[:-4]} data")

    history.append(seer.fit([wap, shl, trades, dates], out1,
                            epochs=25, validation_split=0.2, verbose=2, 
                        callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, min_delta=1e-5),
                        keras.callbacks.ReduceLROnPlateau(monitor="val_loss",min_delta=0.0005, factor=0.5, patience=3, min_lr=1e-6),
                        keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, save_best_only=True)]))
# Out:
# Training on infosys data
# Epoch 1/25
# 32/32 - 73s - loss: 0.7142 - categorical_accuracy: 0.6298 - val_loss: 0.7339 - val_categorical_accuracy: 0.3189 - lr: 1.5625e-06 - 73s/epoch - 2s/step
# Epoch 2/25
# 32/32 - 44s - loss: 0.6718 - categorical_accuracy: 0.5903 - val_loss: 0.7207 - val_categorical_accuracy: 0.2598 - lr: 1.5625e-06 - 44s/epoch - 1s/step
# Epoch 3/25
# 32/32 - 43s - loss: 0.6411 - categorical_accuracy: 0.6545 - val_loss: 0.7233 - val_categorical_accuracy: 0.1457 - lr: 1.5625e-06 - 43s/epoch - 1s/step
# Epoch 4/25
# 32/32 - 45s - loss: 0.6313 - categorical_accuracy: 0.6338 - val_loss: 0.7278 - val_categorical_accuracy: 0.1535 - lr: 1.5625e-06 - 45s/epoch - 1s/step
# Epoch 5/25
# 32/32 - 43s - loss: 0.6310 - categorical_accuracy: 0.6041 - val_loss: 0.7324 - val_categorical_accuracy: 0.1614 - lr: 1.5625e-06 - 43s/epoch - 1s/step
# Epoch 6/25
# 32/32 - 45s - loss: 0.6258 - categorical_accuracy: 0.5874 - val_loss: 0.7332 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 7/25
# 32/32 - 43s - loss: 0.6228 - categorical_accuracy: 0.5686 - val_loss: 0.7335 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 43s/epoch - 1s/step
# Epoch 8/25
# 32/32 - 45s - loss: 0.6185 - categorical_accuracy: 0.6022 - val_loss: 0.7345 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 9/25
# 32/32 - 45s - loss: 0.6213 - categorical_accuracy: 0.5775 - val_loss: 0.7358 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 10/25
# 32/32 - 43s - loss: 0.6162 - categorical_accuracy: 0.5814 - val_loss: 0.7401 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 43s/epoch - 1s/step
# Epoch 11/25
# 32/32 - 43s - loss: 0.6145 - categorical_accuracy: 0.5676 - val_loss: 0.7381 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 43s/epoch - 1s/step
# Epoch 12/25
# 32/32 - 45s - loss: 0.6127 - categorical_accuracy: 0.5923 - val_loss: 0.7425 - val_categorical_accuracy: 0.1614 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Training on tata steel data
# Epoch 1/25
# 32/32 - 46s - loss: 0.8220 - categorical_accuracy: 0.6308 - val_loss: 0.7024 - val_categorical_accuracy: 0.6142 - lr: 1.0000e-06 - 46s/epoch - 1s/step
# Epoch 2/25
# 32/32 - 43s - loss: 0.7783 - categorical_accuracy: 0.5370 - val_loss: 0.6971 - val_categorical_accuracy: 0.4724 - lr: 1.0000e-06 - 43s/epoch - 1s/step
# Epoch 3/25
# 32/32 - 45s - loss: 0.7455 - categorical_accuracy: 0.5370 - val_loss: 0.7003 - val_categorical_accuracy: 0.3898 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 4/25
# 32/32 - 45s - loss: 0.7323 - categorical_accuracy: 0.5647 - val_loss: 0.7100 - val_categorical_accuracy: 0.3386 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 5/25
# 32/32 - 43s - loss: 0.7081 - categorical_accuracy: 0.5726 - val_loss: 0.7263 - val_categorical_accuracy: 0.2047 - lr: 1.0000e-06 - 43s/epoch - 1s/step
# Epoch 6/25
# 32/32 - 45s - loss: 0.7014 - categorical_accuracy: 0.5834 - val_loss: 0.7430 - val_categorical_accuracy: 0.1417 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 7/25
# 32/32 - 45s - loss: 0.6896 - categorical_accuracy: 0.5913 - val_loss: 0.7538 - val_categorical_accuracy: 0.1220 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 8/25
# 32/32 - 45s - loss: 0.6849 - categorical_accuracy: 0.6436 - val_loss: 0.7638 - val_categorical_accuracy: 0.1024 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 9/25
# 32/32 - 45s - loss: 0.6764 - categorical_accuracy: 0.6229 - val_loss: 0.7691 - val_categorical_accuracy: 0.1024 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 10/25
# 32/32 - 45s - loss: 0.6702 - categorical_accuracy: 0.6338 - val_loss: 0.7781 - val_categorical_accuracy: 0.0748 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 11/25
# 32/32 - 45s - loss: 0.6664 - categorical_accuracy: 0.6565 - val_loss: 0.7868 - val_categorical_accuracy: 0.0591 - lr: 1.0000e-06 - 45s/epoch - 1s/step
# Epoch 12/25
# 32/32 - 43s - loss: 0.6617 - categorical_accuracy: 0.6634 - val_loss: 0.7947 - val_categorical_accuracy: 0.0433 - lr: 1.0000e-06 - 43s/epoch - 1s/step

# %%
testing = []
companies = ["tata chemicals.csv"]
#companies = ["edelweiss.csv", "asian paints new.csv"]
for com in companies:
    model_in = np.load(f"input {com[:-4]}.npy")
    wap = model_in[:,:,:,0].reshape((-1, lb, lb, 1))
    shl = model_in[:,:,:,1].reshape((-1, lb, lb, 1))
    trades = model_in[:,:,:,2].reshape((-1, lb, lb, 1))
    dates = model_in[:,:,:,3].reshape((-1,lb,lb,1))
    model_out = np.load(f"output {com[:-4]}.npy")
    out1 = model_out[:,0].reshape((-1,1))
    out2 = model_out[:,1].reshape((-1,1)) 

    #testing.append(seer.evaluate([wap, open, shl, sco, trades, day], [out1, out2]))

# %%
seer.evaluate([wap, shl, trades, dates], out1)
# Out:
# 40/40 [==============================] - 15s 378ms/step - loss: 0.7256 - categorical_accuracy: 0.1350
# [0.7255608439445496, 0.1349644809961319]

# %%
ex = np.arange(0,300)
predict = seer.predict([wap[ex], shl[ex], trades[ex], dates[ex]])
# predict = predict[0]
predict.shape
# Out:
# 10/10 [==============================] - 4s 387ms/step
# (300, 2)

# %%
ans = []
for i in range(len(ex)):
    ans.append(np.where(max(predict[i])==predict[i])[0][0])
out = model_out[ex, 0]

# %%
plt.plot(ex, out, ex, ans)
plt.legend(["Actual", "Predict"])
